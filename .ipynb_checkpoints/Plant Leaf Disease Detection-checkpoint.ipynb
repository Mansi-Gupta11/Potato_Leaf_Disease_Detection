# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
 # !ls "/content/drive/MyDrive/Potato_Disease_detection"
# Out:
# model

# %%
# !ls "/content/drive/MyDrive/Potato_Disease_detection/PlantVillage"
# Out:
# ls: cannot access '/content/drive/MyDrive/Potato_Disease_detection/PlantVillage': No such file or directory

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
import tensorflow as tf
from keras.preprocessing import image
from tensorflow.keras.utils import img_to_array, array_to_img
from keras.models import Sequential
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
print(len("/content/drive/MyDrive/Potato_Disease_detection/PlantVillage/Potato___healthy"))
# Out:
# 77

# %% [markdown]
# Visualize

# %%
plt.figure(figsize=(12,12))
path= "/content/drive/MyDrive/Colab Notebooks/Potato_Disease_detection/PlantVillage/Potato___Late_blight"
for i in range(1,17):
  plt.subplot(4,4,i)
  plt.tight_layout()
  rand_img=imread(path + '/' + random.choice(sorted(os.listdir(path))))
  plt.imshow(rand_img)
  plt.xlabel(rand_img.shape[1],fontsize=10)
  plt.ylabel(rand_img.shape[0],fontsize=10)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Converting image into numpy and normalize them

# %%
def convert_image_to_array(image_dir):
  try:
    image=cv2.imread(image_dir)
    if image is not None:
      image=cv2.resize(image,(256,256))
      return img_to_array(image)
    else:
      return np.array([])
  except Exception as e:
    print(f"Error : (e)")
    return None

# %%
dir="/content/drive/MyDrive/Colab Notebooks/Potato_Disease_detection/PlantVillage"
image_list,label_list=[],[]
all_labels=['Potato___Early_blight','Potato___healthy','Potato___Late_blight']
binary_labels=[0,1,2]
temp=-1

for directory in ['Potato___Early_blight', 'Potato___healthy','Potato___Late_blight']:
  plant_image_list=listdir(f"{dir}/{directory}")
  temp+=1
  for files in plant_image_list:
    image_path=f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# Visyalize the class count and check for class imabalance

# %%
label_counts=pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 1    152
# 0    149
# 2    148
# dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(image_list,label_list,test_size=0.2,random_state=10)

# %%
x_train=np.array(x_train,dtype=np.float16)/  255.0
x_test=np.array(x_test,dtype=np.float16)/ 255.0
x_train=x_train.reshape(-1,256,256,3)
x_test=x_test.reshape(-1,256,256,3)

# %%
y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

# %% [markdown]
# Creating the model architecture

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same", input_shape=(256, 256, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_18 (Conv2D)          (None, 256, 256, 32)      896
#
#  max_pooling2d_16 (MaxPoolin  (None, 85, 85, 32)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 85, 85, 16)        4624
#
#  max_pooling2d_17 (MaxPoolin  (None, 42, 42, 16)       0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 28224)             0
#
#  dense_16 (Dense)            (None, 8)                 225800
#
#  dense_17 (Dense)            (None, 3)                 27
#
# ...
# Total params: 231,347
# Trainable params: 231,347
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(0.0001),metrics=['accuracy'])

# %%
x_train,x_val,y_train,y_val=train_test_split(x_train,y_train,test_size=0.2,random_state=10)

# %%
epochs = 50
batch_size = 128  # Set the batch size to an appropriate value, like 32, 64, or 128

history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 3/3 [==============================] - 20s 6s/step - loss: 1.1056 - accuracy: 0.3554 - val_loss: 1.0957 - val_accuracy: 0.3611
# Epoch 2/50
# 3/3 [==============================] - 13s 3s/step - loss: 1.0813 - accuracy: 0.4355 - val_loss: 1.0755 - val_accuracy: 0.3472
# Epoch 3/50
# 3/3 [==============================] - 12s 3s/step - loss: 1.0719 - accuracy: 0.3380 - val_loss: 1.0657 - val_accuracy: 0.3333
# Epoch 4/50
# 3/3 [==============================] - 11s 4s/step - loss: 1.0536 - accuracy: 0.3449 - val_loss: 1.0386 - val_accuracy: 0.6528
# Epoch 5/50
# 3/3 [==============================] - 13s 4s/step - loss: 1.0300 - accuracy: 0.5889 - val_loss: 1.0333 - val_accuracy: 0.4861
# Epoch 6/50
# 3/3 [==============================] - 11s 3s/step - loss: 1.0246 - accuracy: 0.5436 - val_loss: 1.0120 - val_accuracy: 0.6667
# Epoch 7/50
# 3/3 [==============================] - 11s 3s/step - loss: 0.9996 - accuracy: 0.7666 - val_loss: 0.9811 - val_accuracy: 0.7361
# ...

# %%
model.save("/content/drive/MyDrive/Colab Notebooks/Potato_Disease_detection/disease.h5")

# %%
plt.figure(figsize=(12,5))
plt.plot(history.history['accuracy'],color='r')
plt.plot(history.history['val_accuracy'],color='b')
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.legend(['train','val'])
plt.show()

# %%
print("Calculating model accuracy")
scores=model.evaluate(x_test,y_test)
print(f"Test Accuracy:{scores[1]*100}")
# Out:
# Calculating model accuracy
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4343 - accuracy: 0.8444
# Test Accuracy:84.44444537162781

# %%
y_pred=model.predict(x_test)
# Out:
# 3/3 [==============================] - 1s 304ms/step

# %%
img=array_to_img(x_test[1])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7887DA3F3F10>

# %%
print("Original Label",all_labels[np.argmax(y_test[1])])
print("Predicted Label",all_labels[np.argmax(y_pred[4])])
print(y_pred[2])
# Out:
# Original Label Potato___Early_blight
# Predicted Label Potato___Early_blight
# [0.00518358 0.98390704 0.0109093 ]

# %%
for i in range(50):
  print(all_labels[np.argmax(y_test[i])], "_",all_labels[np.argmax(y_pred[i])])
# Out:
# Potato___healthy _ Potato___healthy
# Potato___Early_blight _ Potato___Early_blight
# Potato___healthy _ Potato___healthy
# Potato___healthy _ Potato___healthy
# Potato___Early_blight _ Potato___Early_blight
# Potato___healthy _ Potato___healthy
# Potato___Early_blight _ Potato___Early_blight
# Potato___healthy _ Potato___healthy
# Potato___healthy _ Potato___healthy
# Potato___healthy _ Potato___healthy
# Potato___healthy _ Potato___Late_blight
# Potato___Late_blight _ Potato___Late_blight
# Potato___Early_blight _ Potato___Early_blight
# Potato___healthy _ Potato___healthy
# Potato___Late_blight _ Potato___Early_blight
# Potato___Early_blight _ Potato___Early_blight
# Potato___Early_blight _ Potato___Early_blight
# Potato___healthy _ Potato___healthy
# Potato___Early_blight _ Potato___Early_blight
# Potato___Late_blight _ Potato___Late_blight
# Potato___Early_blight _ Potato___Early_blight
# Potato___Late_blight _ Potato___healthy
# Potato___Early_blight _ Potato___Early_blight
# ...
